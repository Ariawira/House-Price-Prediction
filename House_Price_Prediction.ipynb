# %% [markdown]
# **Import the Libraries**

# %%
 import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
#  **Import the Dataset**

# %%
 from sklearn.datasets import load_boston
boston = load_boston()

# %%
 boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
 print (boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
 df = pd.DataFrame(boston.data)

# %%
 df.columns = boston.feature_names

# %% [markdown]
#  **Display the Dataset**

# %%
 df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %% [markdown]
# Di sini kita bisa melihat bahwa tidak ada Variabel Target yang ditampilkan, jadi mari kita tambahkan Variabel Target.

# %% [markdown]
# **CATATAN:**
#
# kami telah mengganti nama **MEDV** menjadi **PRICE** untuk lebih mudah dipahami.

# %% [markdown]
#  **Adding the Dependent Variable**

# %%
 df['PRICE'] = boston.target
print(df.head(10))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  PRICE
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# 5  0.02985   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.12   5.21   28.7
# 6  0.08829  12.5   7.87   0.0  0.524  ...  311.0     15.2  395.60  12.43   22.9
# 7  0.14455  12.5   7.87   0.0  0.524  ...  311.0     15.2  396.90  19.15   27.1
# 8  0.21124  12.5   7.87   0.0  0.524  ...  311.0     15.2  386.63  29.93   16.5
# 9  0.17004  12.5   7.87   0.0  0.524  ...  311.0     15.2  386.71  17.10   18.9
#
# [10 rows x 14 columns]

# %% [markdown]
#  **Display the Final Ready Dataset**

# %%
 df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  PRICE
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
#
# [5 rows x 14 columns]

# %% [markdown]
#  **Dataset Shape**

# %%
 df.shape
# Out:
# (506, 14)

# %% [markdown]
#  **Dataset description**

# %%
 df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT       PRICE
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677083   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %% [markdown]
#  **Exploratory Data Analysis**

# %% [markdown]
# Di sini, kita akan melihat beberapa hubungan antara variabel Independen dan Variabel Dependen.

# %% [markdown]
# **1. Crime Rate & PRICE**

# %%
 plt.figure(figsize=(10,5))
sns.regplot(x=df.CRIM, y=df.PRICE)
plt.title('Relationship between CRIME Rate and Price of the Houses')
plt.xlabel('Per capita crime rate by town (CRIM)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
#  **Negative Linear Relation:** Di sini, kita dapat melihat bahwa, ketika Tingkat Kejahatan meningkat, Harga Rumah menurun.

# %% [markdown]
# **2. Average Number of Rooms & PRICE**

# %%
 plt.figure(figsize=(10,5))
sns.regplot(x=df.RM, y=df.PRICE)
plt.title('Relationship between Avg. No. of Rooms and Price of the Houses')
plt.xlabel('Average number of rooms per dwelling(RM)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Positive Linear Relation:** Di sini, kita dapat melihat bahwa, dengan meningkatnya Jumlah Kamar, Harga Rumah meningkat.

# %% [markdown]
# **3. Pupil-Teacher Ratio in Locality & PRICE**

# %%
 plt.figure(figsize=(10,5))
sns.regplot(x=df.PTRATIO, y=df.PRICE)
plt.title('Relationship between Pupil-Teacher Ratio and Price of the Houses')
plt.xlabel('Pupil-Teacher ratio by town(PTRATIO)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Di sini, kita dapat melihat bahwa, ketika rasio Jumlah Murid-Guru meningkat, Harga Rumah turun.

# %% [markdown]
#  **4. Land Zone Proportion & PRICE**

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=df.ZN, y=df.PRICE)
plt.title('Relationship between Land Zone Proportion and Price of the Houses')
plt.xlabel('proportion of residential land zoned for lots over 25,000 sq.ft.(ZN)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Positive Lineaar Relation:** Di sini, kita dapat melihat bahwa, seiring dengan meningkatnya proporsi tanah perumahan yang dikategorikan untuk kavling di atas 25.000 sq.ft. (ZN), Harga Rumah meningkat.

# %% [markdown]
#  **5. Non-retail Business acres per town Proportion & PRICE**

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=df.INDUS, y=df.PRICE)
plt.title('Relationship between Non-retail Business Proportion and Price of the Houses')
plt.xlabel('proportion of non-retail business acres per town(INDUS)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Di sini, kita dapat melihat bahwa, ketika proporsi hektar bisnis non-ritel per kota meningkat, Harga Rumah menurun.

# %% [markdown]
# **6. Nitric Oxides Concentration & PRICE**

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=df.NOX, y=df.PRICE)
plt.title('Relationship between Nitric Oxides Concentration and Price of the Houses')
plt.xlabel('Nitric Oxides Concentration (parts per 10 million(NOX)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Di sini, kita dapat melihat bahwa dengan meningkatnya Konsentrasi Oksida Nitrat, Harga Rumah menurun.

# %% [markdown]
#  **Correlation Matrix**

# %%
plt.figure(figsize=(16,11))
sns.heatmap(df.corr(),square=True,annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Di sini, kita dapat melihat bahwa **RAD** & **PAJAK** Sangat Berkorelasi dengan HARGA.

# %%
plt.hist(df.RM)
plt.title('RM')
plt.xlabel('Avg. No. of Rooms per dwelling')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Di sini, kita dapat melihat bahwa Sebagian Besar Hunian memiliki 6 hingga 7 kamar.

# %% [markdown]
#  **Linear Regression: Using Sklearn**

# %% [markdown]
# Memisahkan dataset menjadi Train dan Test Set.

# %%
X = df.drop('PRICE',axis=1)
y = df['PRICE']

# %%
 from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
 print(X_train.shape)
print(X_test.shape)
# Out:
# (354, 13)
# (152, 13)

# %%
 from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()
model.fit(X_train,y_train)
print('Score = ',model.score(X,y))
# Out:
# Score =  0.7378284679886173

# %% [markdown]
#  **Predictions:**

# %%
Prediction = model.predict(X_test)

# %%
plt.hist(model.predict(X_test),bins=30)
plt.title("PREDICTION PRICE")
plt.xlabel("Predicted Price")
plt.ylabel("Frequency")
plt.show()

# %%
sns.regplot(x = model.predict(X_test), y = y_test, data=Prediction, fit_reg=True)
plt.xlabel("Predicted Prices")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')

# %%
 print('MAE:', metrics.mean_absolute_error(y_test, Prediction))
print('MSE:', metrics.mean_squared_error(y_test, Prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, Prediction)))
# Out:
# MAE: 3.60990406038182
# MSE: 27.195965766883308
# RMSE: 5.214975145375413

# %%
 sns.displot((y_test-Prediction),bins=50,color='red')

# %%
 print(model.intercept_)
 
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
# 37.9371077418333
#          Coefficient
# CRIM       -0.121310
# ZN          0.044466
# INDUS       0.011342
# CHAS        2.511246
# NOX       -16.231253
# RM          3.859068
# AGE        -0.009985
# DIS        -1.500270
# RAD         0.242143
# TAX        -0.011072
# PTRATIO    -1.017753
# B           0.006814
# LSTAT      -0.486738

# %% [markdown]
# **Interpretation:**

# %% [markdown]
# 1.Koefisien RM memberi kita hasil (3,859068)
#
# 2.Kenaikan RM meningkatkan HARGA rumah, yaitu kenaikan $3.8590 untuk setiap 1 Unit.
